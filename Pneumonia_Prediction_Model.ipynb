# %% [markdown]
# # PNEUMONIA CLASSIFICATION MODEL USING CONVOLUTIONAL NEURAL NETWORKS IN TENSORFLOW AND KERAS.

# %%
import os

# %%
# Mounting google drive, where the dataset is.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# confirming that the path to the dataset
os.listdir(os.path.join('drive','MyDrive','data'))
# Out:
# ['train', 'test', 'val']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import os
import matplotlib.pyplot as plt

# %%
# Paths to dataset
train_data_dir = os.path.join('drive','MyDrive','data','train')
val_data_dir = os.path.join('drive','MyDrive','data','val')
test_data_dir = os.path.join('drive','MyDrive','data','test')

# %%
# set our parameters
img_height,img_width = 128,128
batch_size = 32
num_classes = 2

# %%
# Data augmentation and normalization for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
# Data normalization for validation and test
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Load and preprocess data
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

val_generator = val_datagen.flow_from_directory(
    val_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 4464 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# Create the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
steps_per_epoch = max(train_generator.samples // batch_size, 1)
validation_steps = max(val_generator.samples // batch_size, 1)

history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=20,
    validation_data=val_generator,
    validation_steps=validation_steps
)
# Out:
# Epoch 1/20
# 139/139 [==============================] - 275s 2s/step - loss: 0.4665 - accuracy: 0.7888 - val_loss: 0.3884 - val_accuracy: 0.8125
# Epoch 2/20
# 139/139 [==============================] - 222s 2s/step - loss: 0.2872 - accuracy: 0.8854 - val_loss: 0.4382 - val_accuracy: 0.7500
# Epoch 3/20
# 139/139 [==============================] - 221s 2s/step - loss: 0.2365 - accuracy: 0.9079 - val_loss: 1.0233 - val_accuracy: 0.5625
# Epoch 4/20
# 139/139 [==============================] - 230s 2s/step - loss: 0.2215 - accuracy: 0.9136 - val_loss: 0.8678 - val_accuracy: 0.6875
# Epoch 5/20
# 139/139 [==============================] - 227s 2s/step - loss: 0.1980 - accuracy: 0.9233 - val_loss: 1.1522 - val_accuracy: 0.6250
# Epoch 6/20
# 139/139 [==============================] - 232s 2s/step - loss: 0.1803 - accuracy: 0.9307 - val_loss: 0.6497 - val_accuracy: 0.7500
# Epoch 7/20
# ...

# %%
# Save the trained model
model.save(pneumonia_model.h5)
# model.save('pneumonia_model.keras')

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print(f'Test loss: {test_loss}, Test accuracy: {test_acc}')

# %%
# Plot training & validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(20)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The validation data was too small, hence the lack of a clear trend.
